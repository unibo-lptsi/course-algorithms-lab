# %% [markdown]
# # Plotting running times of search algoritms
#
# Basic imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %% [markdown]
# Let's plot how capacity evolves with different algorithms for dynamic array capacity expansion
#
# ```
#
# ```

# %%
def linear_expansion(n, dgrow = 500, dshrink = 1000):
    arr = np.array([])
    # extending (resize(n+1))
    c = 1
    for i in range(n):
        if i>=c:
            c = i + dgrow
        arr = np.append(arr, [c])
    # contracting (resize(n-1))
    for i in range(n,0,-1): 
        if c-i > dshrink:
            c = i + dgrow
        arr = np.append(arr, [c])
    return arr

def geometric_expansion(n, fgrow = 5., fshrink = 5.5):
    arr = np.array([])
    # extending (resize(n+1))
    c = 1
    for i in range(n):
        if i>=c:
            c = i * fgrow
        arr = np.append(arr, [c])
    # contracting (resize(n-1))
    for i in range(n,0,-1):
        if float(c)/i > fshrink:
            c = i * fgrow
        arr = np.append(arr, [c])
    return arr

# %%
n = 10000
xs = np.arange(2*n)
# xs = np.append(xs, xs)

dgrow = 500
dshrink = 2000
fgrow = 2.0
fshrink = 3.5
fig, ax1 = plt.subplots(1, 1)
fig.set_size_inches(12,4)
ax1.axvline(x=n, linestyle='--')
ax1.set_ylabel("capacity")
ax1.set_xlabel("num of unit resize ops")
ax1.plot(xs, linear_expansion(n, dgrow, dshrink), label=f"linear(dgrow={dgrow},dshrink={dshrink})", color='red')
ax1.plot(xs, geometric_expansion(n, fgrow, fshrink), label=f"geometric(fgrow={fgrow},fshrink={fshrink})", color='blue')
ax1.legend(loc='upper left')
fig.show()
# Out:
# /tmp/ipykernel_47096/821673369.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
